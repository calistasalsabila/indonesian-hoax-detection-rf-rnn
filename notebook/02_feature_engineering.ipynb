# %% [markdown]
# ## 2. Feature Engineering

# %% [markdown]
# ### Importing the Library

# %%
import pickle

# %% [markdown]
# ### Load the Dataset

# %%
X_train = pickle.load(open("../data/processed/X_train.pkl", "rb"))
X_test  = pickle.load(open("../data/processed/X_test.pkl", "rb"))
y_train = pickle.load(open("../data/processed/y_train.pkl", "rb"))
y_test  = pickle.load(open("../data/processed/y_test.pkl", "rb"))

# %% [markdown]
# ### Save the Dataset

# %%
pickle.dump(tfidf, open("../data/processed/tfidf.pkl", "wb"))
pickle.dump(tokenizer, open("../data/processed/tokenizer.pkl", "wb"))

pickle.dump(X_train_tfidf, open("../data/processed/X_train_tfidf.pkl", "wb"))
pickle.dump(X_test_tfidf,  open("../data/processed/X_test_tfidf.pkl", "wb"))

pickle.dump(X_train_pad, open("../data/processed/X_train_pad.pkl", "wb"))
pickle.dump(X_test_pad,  open("../data/processed/X_test_pad.pkl", "wb"))
